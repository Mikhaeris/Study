# %% [markdown]
# 1) Разархивирование архива в папку data

# %%
# !mkdir -p /content/data && unzip -jo "/content/14 Вариант.zip" -d "/content/data"
# Out:
# Archive:  /content/14 Вариант.zip
#   inflating: /content/data/aug_train.csv
#   inflating: /content/data/Readme.txt

# %% [markdown]
# 2) Загрузка датасета в таблицу в pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/data/aug_train.csv")
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# 3) Построение гистограммы

# %%
df['city'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# 4) Получение минимального значения по одному из признаков

# %%
print(df['training_hours'].min())
# Out:
# 1

# %% [markdown]
# 5) Получение максимлаьного значения по одному из признаков

# %%
print(df['enrollee_id'].max())
# Out:
# 33380

# %% [markdown]
# 6) вычисление медианы и среднего

# %%
th = df['training_hours'];
print('median:', th.median(), 'average:', th.mean())
# Out:
# median: 47.0 average: 65.36689633573442

# %% [markdown]
# 7) Подсчет вхождений для нечисловых признаков

# %%
for c in df.select_dtypes(exclude='number'):
    print(c)
    print(df[c].value_counts(dropna=False).head(10).to_dict(), "\n")
# Out:
# city
# {'city_103': 4355, 'city_21': 2702, 'city_16': 1533, 'city_114': 1336, 'city_160': 845, 'city_136': 586, 'city_67': 431, 'city_75': 305, 'city_102': 304, 'city_104': 301}
#
# gender
# {'Male': 13221, nan: 4508, 'Female': 1238, 'Other': 191}
#
# relevent_experience
# {'Has relevent experience': 13792, 'No relevent experience': 5366}
#
# enrolled_university
# {'no_enrollment': 13817, 'Full time course': 3757, 'Part time course': 1198, nan: 386}
#
# education_level
# {'Graduate': 11598, 'Masters': 4361, 'High School': 2017, nan: 460, 'Phd': 414, 'Primary School': 308}
#
# major_discipline
# {'STEM': 14492, nan: 2813, 'Humanities': 669, 'Other': 381, 'Business Degree': 327, 'Arts': 253, 'No Major': 223}
#
# experience
# {'>20': 3286, '5': 1430, '4': 1403, '3': 1354, '6': 1216, '2': 1127, '7': 1028, '10': 985, '9': 980, '8': 802}
#
# company_size
# ...
